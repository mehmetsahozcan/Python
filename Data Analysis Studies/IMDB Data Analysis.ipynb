# %%
import pandas as pd

# %%
df = pd.read_csv("imdb.csv")
result = df

# %%
result.head()
# Out:
#                     Movie_Title  YR_Released  Rating  Num_Reviews   Movie_ID  \
# 0             Code Name: K.O.Z.         2015     1.4        24623  tt4458206
# 1              Saving Christmas         2014     1.5        12765  tt4009460
# 2  Superbabies: Baby Geniuses 2         2004     1.6        26505  tt0270846
# 3             Daniel the Wizard         2004     1.6        13295  tt0421051
# 4      Manos: The Hands of Fate         1966     1.7        31808  tt0060666
#
#               Record  Runtime
# 0  Bottom 250 Movies    114.0
# 1  Bottom 250 Movies     80.0
# 2  Bottom 250 Movies     88.0
# 3  Bottom 250 Movies     81.0
# 4  Bottom 250 Movies     70.0

# %% [markdown]
# #### SORU 1
# Dosya hakkındaki bilgiler

# %%
result.shape
# Out:
# (850, 7)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Movie_Title  850 non-null    object
#  1   YR_Released  850 non-null    int64
#  2   Rating       850 non-null    float64
#  3   Num_Reviews  850 non-null    int64
#  4   Movie_ID     850 non-null    object
#  5   Record       850 non-null    object
#  6   Runtime      849 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 46.6+ KB

# %%
result.columns
# Out:
# Index(['Movie_Title', 'YR_Released', 'Rating', 'Num_Reviews', 'Movie_ID',
#        'Record', 'Runtime'],
#       dtype='object')

# %% [markdown]
# #### SORU 2
# İlk 5  kaydı getirin

# %%
result.head()
# Out:
#                     Movie_Title  YR_Released  Rating  Num_Reviews   Movie_ID  \
# 0             Code Name: K.O.Z.         2015     1.4        24623  tt4458206
# 1              Saving Christmas         2014     1.5        12765  tt4009460
# 2  Superbabies: Baby Geniuses 2         2004     1.6        26505  tt0270846
# 3             Daniel the Wizard         2004     1.6        13295  tt0421051
# 4      Manos: The Hands of Fate         1966     1.7        31808  tt0060666
#
#               Record  Runtime
# 0  Bottom 250 Movies    114.0
# 1  Bottom 250 Movies     80.0
# 2  Bottom 250 Movies     88.0
# 3  Bottom 250 Movies     81.0
# 4  Bottom 250 Movies     70.0

# %%
#ilk 10 kayıt
result.head(10)
# Out:
#                      Movie_Title  YR_Released  Rating  Num_Reviews   Movie_ID  \
# 0              Code Name: K.O.Z.         2015     1.4        24623  tt4458206
# 1               Saving Christmas         2014     1.5        12765  tt4009460
# 2   Superbabies: Baby Geniuses 2         2004     1.6        26505  tt0270846
# 3              Daniel the Wizard         2004     1.6        13295  tt0421051
# 4       Manos: The Hands of Fate         1966     1.7        31808  tt0060666
# 5                   Pledge This!         2006     1.7        15836  tt0417056
# 6  Dünyayi Kurtaran Adam'in Oglu         2006     1.8        14110  tt0808240
# 7                     Foodfight!         2012     1.8         5740  tt0249516
# 8     Birdemic: Shock and Terror         2010     1.8        15919  tt1316037
# 9                       Álom.net         2009     1.9         8502  tt1309000
#
#               Record  Runtime
# 0  Bottom 250 Movies    114.0
# 1  Bottom 250 Movies     80.0
# ...

# %%
#son 5 kayıt
result.tail()
# Out:
#                                            Movie_Title  YR_Released  Rating  \
# 845  Pirates of the Caribbean: The Curse of the Bla...         2003     8.0
# 846                   What Ever Happened to Baby Jane?         1962     8.0
# 847                                       Paris, Texas         1984     8.0
# 848                                           Drishyam         2015     8.0
# 849                                                 PK         2014     8.0
#
#      Num_Reviews   Movie_ID          Record  Runtime
# 845       872441  tt0325980  Top 250 Movies    143.0
# 846        37906  tt0056687  Top 250 Movies    134.0
# 847        55587  tt0087884  Top 250 Movies    145.0
# 848        40777  tt4430212  Top 250 Movies    163.0
# 849       106375  tt2338151  Top 250 Movies    153.0

# %%
#sadece Movie_Title kolonunu alın
result["Movie_Title"]
# Out:
# 0                                      Code Name: K.O.Z.
# 1                                       Saving Christmas
# 2                           Superbabies: Baby Geniuses 2
# 3                                      Daniel the Wizard
# 4                               Manos: The Hands of Fate
#                              ...
# 845    Pirates of the Caribbean: The Curse of the Bla...
# 846                     What Ever Happened to Baby Jane?
# 847                                         Paris, Texas
# 848                                             Drishyam
# 849                                                   PK
# Name: Movie_Title, Length: 850, dtype: object

# %%
#Sadece Movie_Title kolonunu içeren ilk 5 kaydı alın.
result["Movie_Title"].head()
# Out:
# 0               Code Name: K.O.Z.
# 1                Saving Christmas
# 2    Superbabies: Baby Geniuses 2
# 3               Daniel the Wizard
# 4        Manos: The Hands of Fate
# Name: Movie_Title, dtype: object

# %%
#Sadece Movie_Title ve Rating kolonunu içeren ilk 5 kaydı alın.
result[["Movie_Title","Rating"]].head()
# Out:
#                     Movie_Title  Rating
# 0             Code Name: K.O.Z.     1.4
# 1              Saving Christmas     1.5
# 2  Superbabies: Baby Geniuses 2     1.6
# 3             Daniel the Wizard     1.6
# 4      Manos: The Hands of Fate     1.7

# %%
#Sadece Movie_Title ve Rating kolonunu içeren son 7 kaydı alın.
result[["Movie_Title","Rating"]].tail(7)
# Out:
#                                            Movie_Title  Rating
# 843                              The Battle of Algiers     8.0
# 844                               In the Mood for Love     8.0
# 845  Pirates of the Caribbean: The Curse of the Bla...     8.0
# 846                   What Ever Happened to Baby Jane?     8.0
# 847                                       Paris, Texas     8.0
# 848                                           Drishyam     8.0
# 849                                                 PK     8.0

# %%
#Sadece Movie_Title ve Rating kolonunu içeren ikinci 5 kaydı alın.
result[5:][["Movie_Title","Rating"]].head()
# Out:
#                      Movie_Title  Rating
# 5                   Pledge This!     1.7
# 6  Dünyayi Kurtaran Adam'in Oglu     1.8
# 7                     Foodfight!     1.8
# 8     Birdemic: Shock and Terror     1.8
# 9                       Álom.net     1.9

# %%
# 11- Sadece Movie_Title ve Rating kolonunu içeren ve imdb puanı 8.0 ve üstünde olan kayıtlardan ilk 50 tanesini alınız.
result = df[df["Rating"] > 8][["Movie_Title","Rating"]].head(50)
print(result)
# Out:
#                                            Movie_Title  Rating
# 100                           The Shawshank Redemption     9.2
# 101                                      The Godfather     9.2
# 102                             The Godfather: Part II     9.0
# 103                                    The Dark Knight     9.0
# 104                                       12 Angry Men     8.9
# 105                                   Schindler's List     8.9
# 106      The Lord of the Rings: The Return of the King     8.9
# 107                                       Pulp Fiction     8.9
# 108                                         Fight Club     8.8
# 109  The Lord of the Rings: The Fellowship of the Ring     8.8
# 110                                       Forrest Gump     8.8
# 111     Star Wars: Episode V - The Empire Strikes Back     8.8
# 112                                          Inception     8.7
# 113              The Lord of the Rings: The Two Towers     8.7
# ...

# %%
result = df[(df["YR_Released"]>=2014) & (df["YR_Released"]<=2015)][["Movie_Title","YR_Released"]]
print(result)
# Out:
#                                     Movie_Title  YR_Released
# 0                             Code Name: K.O.Z.         2015
# 1                              Saving Christmas         2014
# 21                                 Potato Salad         2015
# 29                                   Humshakals         2014
# 49                              United Passions         2014
# ..                                          ...          ...
# 796                                   Spotlight         2015
# 797                          Mad Max: Fury Road         2015
# 814  Star Wars: Episode VII - The Force Awakens         2015
# 848                                    Drishyam         2015
# 849                                          PK         2014
#
# [69 rows x 2 columns]

# %%
result = df[(df["Num_Reviews"] >= 100000) | ((df["Rating"] >= 8) & (df["Rating"] <= 9))][["Movie_Title","Num_Reviews","Rating"]]
print(result)
# Out:
#                                            Movie_Title  Num_Reviews  Rating
# 100                           The Shawshank Redemption      1829037     9.2
# 101                                      The Godfather      1249333     9.2
# 102                             The Godfather: Part II       860228     9.0
# 103                                    The Dark Knight      1808543     9.0
# 104                                       12 Angry Men       497242     8.9
# ..                                                 ...          ...     ...
# 845  Pirates of the Caribbean: The Curse of the Bla...       872441     8.0
# 846                   What Ever Happened to Baby Jane?        37906     8.0
# 847                                       Paris, Texas        55587     8.0
# 848                                           Drishyam        40777     8.0
# 849                                                 PK       106375     8.0
#
# [573 rows x 3 columns]
