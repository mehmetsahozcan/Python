# %%
import pandas as pd
import seaborn as sns
df = pd.read_excel("C:/Users/ozcan/Desktop/dataset.xlsx")
df.head()
# Out:
#    yaş cinsiyet   göğüsağrısı  kanbasıncı  kolestrol kanşsekeri  kalpatıs  \
# 0   52    Erkek  ASYMPTOMATIC         125        212      <=120       168
# 1   53    Erkek  ASYMPTOMATIC         140        203       >120       155
# 2   70    Erkek  ASYMPTOMATIC         145        174      <=120       125
# 3   61    Erkek  ASYMPTOMATIC         148        203      <=120       161
# 4   62    Kadın  ASYMPTOMATIC         138        294       >120       106
#
#    hedef
# 0  Hayır
# 1  Hayır
# 2  Hayır
# 3  Hayır
# 4  Hayır

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x = "kalpatıs", y = "yaş", hue = "cinsiyet", data = df);

# %%
#yaş azaldıkça kalp atışı artmaktadır.

# %%
sns.lmplot(x = "kolestrol", y = "yaş", hue = "cinsiyet",  col= "hedef", data = df);

# %%
sns.lmplot(x = "kanbasıncı", y = "yaş", hue = "cinsiyet",  col= "hedef", data = df);

# %%
sns.lmplot(x = "kanbasıncı", y = "yaş", hue = "cinsiyet",  col= "hedef", row = "kanşsekeri", data = df);
